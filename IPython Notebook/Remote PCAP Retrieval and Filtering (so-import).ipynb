# %% [markdown]
# # PCAP Data Retrieval and Filtering Notebook (Security Onion Import)
#
# This Jupyter Notebook demonstrates how to retrieve and filter PCAP files from a remote server using the `paramiko` and `scp` libraries. The notebook covers the following main tasks:
#
# 1. Connecting to the remote server via SSH.
# 2. Retrieving PCAP files from the remote server.
# 3. Filtering the retrieved PCAP files based on specific conditions.
#
# The notebook is designed to be executed in sequence, with each cell representing a specific task in the data retrieval and filtering process. It includes explanations, code comments, and sample output to help you understand and visualize each step.
#
# **Prerequisites:**
# - Python environment with required libraries installed (`paramiko`, `scp`, `pandas`).
# - Access to a remote server with the necessary credentials.
# - The `filter_pcap_script.py` script for filtering PCAP files should be available in the same directory.
#
# Feel free to adapt and customize this notebook for your specific use case. Happy data retrieval and filtering!

# %% [markdown]
# # Import Libraries

# %%
import paramiko
import scp
import pandas as pd
from filter_pcap_script import filter_pcap

# %% [markdown]
# # Define Configuration Parameters

# %%
remote_host = "192.168.43.10"
remote_username = "wajdi"
remote_password = "0000"

# %% [markdown]
# # Retrieve and Download PCAP Files

# %%
pcap_info = pd.read_csv('./flow_info.csv')

for _, row in pcap_info.iterrows():
    import_id = row['import.id']
    log_id = row['log.id.uid']
    local_filename = f"./full_pcap_{log_id}.pcap"
    remote_pcap_path = f"/nsm/import/{import_id}/pcap/data.pcap"
    
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    try:
        ssh.connect(remote_host, username=remote_username, password=remote_password)
        print("Connected via SSH")
        with scp.SCPClient(ssh.get_transport()) as scp_client:
            scp_client.get(remote_pcap_path, local_filename)
            print("PCAP file retrieved")
    except (paramiko.AuthenticationException, paramiko.SSHException) as error:
        print("Error:", str(error))
    finally:
        ssh.close()
# Out:
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved
# Connected via SSH
# PCAP file retrieved

# %% [markdown]
# # Filter PCAP Files

# %%
flow_info = pd.read_csv('./flow_info.csv')

for _, row in flow_info.iterrows():
    connection_srcip, connection_dstip, src_port, dst_port, proto = row['source.ip'], row['destination.ip'], row['source.port'], row['destination.port'], row['network.transport']
    log_id = row["log.id.uid"]
    proto = proto.lower()
    filter_condition = (
        f"(ip.src == {connection_srcip} && {proto}.srcport == {src_port} && "
        f"ip.dst == {connection_dstip} && {proto}.dstport == {dst_port}) || "
        f"(ip.src == {connection_dstip} && {proto}.srcport == {dst_port} && "
        f"ip.dst == {connection_srcip} && {proto}.dstport == {src_port})"
    )
    input_path = f'./full_pcap_{log_id}.pcap'
    output_path = f'./filtered_pcap_{log_id}.pcap'
    # !python filter_pcap_script.py $input_path $output_path "$filter_condition"
# Out:
# Filtered pcap saved to ./filtered_pcap_203297560709042.pcap
# Filtered pcap saved to ./filtered_pcap_203297560709042.pcap
# Filtered pcap saved to ./filtered_pcap_1804203672181747.pcap
# Filtered pcap saved to ./filtered_pcap_598413082629892.pcap
# Filtered pcap saved to ./filtered_pcap_1718789661686758.pcap
# Filtered pcap saved to ./filtered_pcap_439340379060212.pcap
# Filtered pcap saved to ./filtered_pcap_1503856613369083.pcap
# Filtered pcap saved to ./filtered_pcap_1227368093728265.pcap
# Filtered pcap saved to ./filtered_pcap_202588916476856.pcap
# Filtered pcap saved to ./filtered_pcap_310555824063105.pcap
# Filtered pcap saved to ./filtered_pcap_2118801499886961.pcap
# Filtered pcap saved to ./filtered_pcap_39539132232217.pcap
# Filtered pcap saved to ./filtered_pcap_998244587245707.pcap
# Filtered pcap saved to ./filtered_pcap_535470451044991.pcap
# Filtered pcap saved to ./filtered_pcap_536531366383629.pcap
# Filtered pcap saved to ./filtered_pcap_1908657457283477.pcap
# Filtered pcap saved to ./filtered_pcap_694607661458988.pcap
# Filtered pcap saved to ./filtered_pcap_512093045941525.pcap
# Filtered pcap saved to ./filtered_pcap_31250002088737.pcap
# Filtered pcap saved to ./filtered_pcap_1424593247215355.pcap
# Filtered pcap saved to ./filtered_pcap_2168941164163292.pcap
# Filtered pcap saved to ./filtered_pcap_112519432508060.pcap
# Filtered pcap saved to ./filtered_pcap_18829035675238.pcap
# Filtered pcap saved to ./filtered_pcap_1670372829728554.pcap
# Filtered pcap saved to ./filtered_pcap_1369914117309693.pcap
# Filtered pcap saved to ./filtered_pcap_353540191261502.pcap
# Filtered pcap saved to ./filtered_pcap_1051042899827580.pcap
# Filtered pcap saved to ./filtered_pcap_130085967183264.pcap
# Filtered pcap saved to ./filtered_pcap_1410035633343427.pcap
# Filtered pcap saved to ./filtered_pcap_1180961424844680.pcap
# Filtered pcap saved to ./filtered_pcap_1519587403598873.pcap
# Filtered pcap saved to ./filtered_pcap_892629572384925.pcap
# Filtered pcap saved to ./filtered_pcap_1460978319362837.pcap
# Filtered pcap saved to ./filtered_pcap_1666571981160167.pcap
# Filtered pcap saved to ./filtered_pcap_1641547373988128.pcap
# Filtered pcap saved to ./filtered_pcap_732081626300164.pcap
# Filtered pcap saved to ./filtered_pcap_611143956954335.pcap
# Filtered pcap saved to ./filtered_pcap_651995558136976.pcap
# Filtered pcap saved to ./filtered_pcap_265575222745835.pcap
# Filtered pcap saved to ./filtered_pcap_2067707012700835.pcap
# Filtered pcap saved to ./filtered_pcap_995255846138329.pcap
# Filtered pcap saved to ./filtered_pcap_1136631156892994.pcap
# Filtered pcap saved to ./filtered_pcap_203297560709042.pcap
# Filtered pcap saved to ./filtered_pcap_1124852228874396.pcap
# Filtered pcap saved to ./filtered_pcap_912264252329927.pcap
# Filtered pcap saved to ./filtered_pcap_2108756261360799.pcap
# Filtered pcap saved to ./filtered_pcap_324047045727830.pcap
# Filtered pcap saved to ./filtered_pcap_1849726819375267.pcap
# Filtered pcap saved to ./filtered_pcap_1460542655334346.pcap
# Filtered pcap saved to ./filtered_pcap_70001897474583.pcap
# Filtered pcap saved to ./filtered_pcap_1334481072621071.pcap
# Filtered pcap saved to ./filtered_pcap_1144418033772050.pcap
# Filtered pcap saved to ./filtered_pcap_1391455963722321.pcap
# Filtered pcap saved to ./filtered_pcap_1520665761208548.pcap
# Filtered pcap saved to ./filtered_pcap_559973920113512.pcap
# Filtered pcap saved to ./filtered_pcap_1242195115535662.pcap
# Filtered pcap saved to ./filtered_pcap_1947911929565611.pcap
# Filtered pcap saved to ./filtered_pcap_2092471939003353.pcap
# Filtered pcap saved to ./filtered_pcap_445802952721295.pcap
# Filtered pcap saved to ./filtered_pcap_1118012579394406.pcap
# Filtered pcap saved to ./filtered_pcap_201732846614969.pcap
# Filtered pcap saved to ./filtered_pcap_1203402972314876.pcap
# Filtered pcap saved to ./filtered_pcap_524581244056627.pcap
# Filtered pcap saved to ./filtered_pcap_253040527119233.pcap
# Filtered pcap saved to ./filtered_pcap_1722982366139430.pcap
# Filtered pcap saved to ./filtered_pcap_736074045873777.pcap
# Filtered pcap saved to ./filtered_pcap_1906592222853419.pcap
# Filtered pcap saved to ./filtered_pcap_68176571298278.pcap
# Filtered pcap saved to ./filtered_pcap_23111629240174.pcap
# Filtered pcap saved to ./filtered_pcap_814927507318483.pcap
# Filtered pcap saved to ./filtered_pcap_1570931948090672.pcap
# Filtered pcap saved to ./filtered_pcap_1437770784402092.pcap
# Filtered pcap saved to ./filtered_pcap_1453026511692808.pcap
# Filtered pcap saved to ./filtered_pcap_1907122685111466.pcap
# Filtered pcap saved to ./filtered_pcap_237877205514477.pcap
# Filtered pcap saved to ./filtered_pcap_23835365187496.pcap
# Filtered pcap saved to ./filtered_pcap_952669289943652.pcap
# Filtered pcap saved to ./filtered_pcap_660867066673657.pcap
# Filtered pcap saved to ./filtered_pcap_2200793233254938.pcap
# Filtered pcap saved to ./filtered_pcap_1423152899448848.pcap
# Filtered pcap saved to ./filtered_pcap_449034991718813.pcap
# Filtered pcap saved to ./filtered_pcap_2140629342419331.pcap
# Filtered pcap saved to ./filtered_pcap_1699076655357933.pcap
# Filtered pcap saved to ./filtered_pcap_1352004645574733.pcap
# Filtered pcap saved to ./filtered_pcap_1831226361405069.pcap
# Filtered pcap saved to ./filtered_pcap_908725370712897.pcap
# Filtered pcap saved to ./filtered_pcap_174397634662349.pcap
# Filtered pcap saved to ./filtered_pcap_743519458516359.pcap
# Filtered pcap saved to ./filtered_pcap_1379928387429835.pcap
# Filtered pcap saved to ./filtered_pcap_415467713673180.pcap
# Filtered pcap saved to ./filtered_pcap_1816533299150270.pcap
# Filtered pcap saved to ./filtered_pcap_2095996096818648.pcap
# Filtered pcap saved to ./filtered_pcap_1025610792189352.pcap
# Filtered pcap saved to ./filtered_pcap_84886255267351.pcap
# Filtered pcap saved to ./filtered_pcap_1854004761883765.pcap
# Filtered pcap saved to ./filtered_pcap_131858170000638.pcap
# Filtered pcap saved to ./filtered_pcap_1847538693370125.pcap
# Filtered pcap saved to ./filtered_pcap_1578519124180035.pcap
# Filtered pcap saved to ./filtered_pcap_479256606854961.pcap
# Filtered pcap saved to ./filtered_pcap_212317958390606.pcap
# Filtered pcap saved to ./filtered_pcap_464121164130891.pcap
# Filtered pcap saved to ./filtered_pcap_1480434982797164.pcap
# Filtered pcap saved to ./filtered_pcap_1881660092523587.pcap
# Filtered pcap saved to ./filtered_pcap_756672868586380.pcap
# Filtered pcap saved to ./filtered_pcap_505737259268557.pcap
# Filtered pcap saved to ./filtered_pcap_1636398139697278.pcap
# Filtered pcap saved to ./filtered_pcap_19153976550583.pcap
# Filtered pcap saved to ./filtered_pcap_295058383044291.pcap
# Filtered pcap saved to ./filtered_pcap_1535792844788454.pcap
# Filtered pcap saved to ./filtered_pcap_1385318673257780.pcap
# Filtered pcap saved to ./filtered_pcap_61124423717815.pcap
# Filtered pcap saved to ./filtered_pcap_752768779611396.pcap
# Filtered pcap saved to ./filtered_pcap_68563311794434.pcap
# Filtered pcap saved to ./filtered_pcap_901462699577400.pcap
# Filtered pcap saved to ./filtered_pcap_1417268946835170.pcap
# Filtered pcap saved to ./filtered_pcap_2156707698727839.pcap
# Filtered pcap saved to ./filtered_pcap_1419747147677999.pcap
# Filtered pcap saved to ./filtered_pcap_530128441416708.pcap
# Filtered pcap saved to ./filtered_pcap_244699952095346.pcap
# Filtered pcap saved to ./filtered_pcap_678392867132702.pcap
# Filtered pcap saved to ./filtered_pcap_1463049034787100.pcap
# Filtered pcap saved to ./filtered_pcap_1288997634902738.pcap
# Filtered pcap saved to ./filtered_pcap_5030049065653.pcap
# Filtered pcap saved to ./filtered_pcap_391714547015589.pcap
# Filtered pcap saved to ./filtered_pcap_520610812884847.pcap
# Filtered pcap saved to ./filtered_pcap_239535270501793.pcap
# Filtered pcap saved to ./filtered_pcap_2029050594391672.pcap
# Filtered pcap saved to ./filtered_pcap_637659433490312.pcap
# Filtered pcap saved to ./filtered_pcap_2084889468510898.pcap
# Filtered pcap saved to ./filtered_pcap_935066596187925.pcap
# Filtered pcap saved to ./filtered_pcap_393982323611047.pcap
# Filtered pcap saved to ./filtered_pcap_1695690276628598.pcap
# Filtered pcap saved to ./filtered_pcap_1426015724919682.pcap
# Filtered pcap saved to ./filtered_pcap_2035772234283861.pcap
# Filtered pcap saved to ./filtered_pcap_1303886187086626.pcap
# Filtered pcap saved to ./filtered_pcap_819066005770323.pcap
# Filtered pcap saved to ./filtered_pcap_2175667934408691.pcap
# Filtered pcap saved to ./filtered_pcap_1963679087545628.pcap
# Filtered pcap saved to ./filtered_pcap_396131990976449.pcap
# Filtered pcap saved to ./filtered_pcap_1645361886087896.pcap
# Filtered pcap saved to ./filtered_pcap_1925383018711450.pcap
# Filtered pcap saved to ./filtered_pcap_1343640438248438.pcap
# Filtered pcap saved to ./filtered_pcap_1631042472194897.pcap
# Filtered pcap saved to ./filtered_pcap_722598909381517.pcap
# Filtered pcap saved to ./filtered_pcap_748506174141851.pcap
# Filtered pcap saved to ./filtered_pcap_826708941095195.pcap
# Filtered pcap saved to ./filtered_pcap_213701145286185.pcap
# Filtered pcap saved to ./filtered_pcap_722839454359641.pcap
# Filtered pcap saved to ./filtered_pcap_1913567599970835.pcap
# Filtered pcap saved to ./filtered_pcap_411048455704771.pcap
# Filtered pcap saved to ./filtered_pcap_1496433938453021.pcap
# Filtered pcap saved to ./filtered_pcap_1941931571078528.pcap
# Filtered pcap saved to ./filtered_pcap_1431212717300425.pcap
# Filtered pcap saved to ./filtered_pcap_281739904470414.pcap
# Filtered pcap saved to ./filtered_pcap_274367595498863.pcap
# Filtered pcap saved to ./filtered_pcap_550759480818756.pcap
# Filtered pcap saved to ./filtered_pcap_1888613878197093.pcap
# Filtered pcap saved to ./filtered_pcap_1618234949833366.pcap
# Filtered pcap saved to ./filtered_pcap_1730108112885869.pcap
# Filtered pcap saved to ./filtered_pcap_2103443852481555.pcap
# Filtered pcap saved to ./filtered_pcap_922415895262044.pcap
# Filtered pcap saved to ./filtered_pcap_2186487049861356.pcap
# Filtered pcap saved to ./filtered_pcap_884072599106001.pcap
# Filtered pcap saved to ./filtered_pcap_1332572413944836.pcap
# Filtered pcap saved to ./filtered_pcap_3627930487028.pcap
# Filtered pcap saved to ./filtered_pcap_759952346360913.pcap
# Filtered pcap saved to ./filtered_pcap_1463787966876498.pcap
# Filtered pcap saved to ./filtered_pcap_1059421091055917.pcap
# Filtered pcap saved to ./filtered_pcap_211034055804005.pcap
# Filtered pcap saved to ./filtered_pcap_390447727017969.pcap
# Filtered pcap saved to ./filtered_pcap_2206196693363268.pcap
# Filtered pcap saved to ./filtered_pcap_206719787894363.pcap
# Filtered pcap saved to ./filtered_pcap_1282901155750374.pcap
# Filtered pcap saved to ./filtered_pcap_372359501413626.pcap
# Filtered pcap saved to ./filtered_pcap_822935932884507.pcap
# Filtered pcap saved to ./filtered_pcap_184922838371196.pcap
# Filtered pcap saved to ./filtered_pcap_2246444865788334.pcap
# Filtered pcap saved to ./filtered_pcap_565658807208164.pcap
# Filtered pcap saved to ./filtered_pcap_318835628409444.pcap
# Filtered pcap saved to ./filtered_pcap_1087589679583013.pcap
# Filtered pcap saved to ./filtered_pcap_1971073064323899.pcap
# Filtered pcap saved to ./filtered_pcap_1910123185863572.pcap
# Filtered pcap saved to ./filtered_pcap_640165783306461.pcap
# Filtered pcap saved to ./filtered_pcap_142544432303319.pcap
# Filtered pcap saved to ./filtered_pcap_2219255611554848.pcap
# Filtered pcap saved to ./filtered_pcap_606126027065006.pcap
# Filtered pcap saved to ./filtered_pcap_27102160893146.pcap
# Filtered pcap saved to ./filtered_pcap_1048544169217835.pcap
# Filtered pcap saved to ./filtered_pcap_1728227040037987.pcap
# Filtered pcap saved to ./filtered_pcap_1164725205342473.pcap
# Filtered pcap saved to ./filtered_pcap_1811351861534045.pcap
# Filtered pcap saved to ./filtered_pcap_669829013520328.pcap
# Filtered pcap saved to ./filtered_pcap_1639793692593320.pcap
# Filtered pcap saved to ./filtered_pcap_2099322983410432.pcap
# Filtered pcap saved to ./filtered_pcap_1401322080691394.pcap
# Filtered pcap saved to ./filtered_pcap_1946280418455429.pcap
# Filtered pcap saved to ./filtered_pcap_1448994074913641.pcap
# Filtered pcap saved to ./filtered_pcap_2191022691302919.pcap
# Filtered pcap saved to ./filtered_pcap_1914476210002885.pcap
# Filtered pcap saved to ./filtered_pcap_1603295094427427.pcap
# Filtered pcap saved to ./filtered_pcap_1472625011720469.pcap
# Filtered pcap saved to ./filtered_pcap_2143166045794418.pcap
# Filtered pcap saved to ./filtered_pcap_1271326341778067.pcap
# Filtered pcap saved to ./filtered_pcap_73988246252053.pcap
# Filtered pcap saved to ./filtered_pcap_1747116381086835.pcap
# Filtered pcap saved to ./filtered_pcap_718673579507573.pcap
# Filtered pcap saved to ./filtered_pcap_868499223057194.pcap
# Filtered pcap saved to ./filtered_pcap_1475068881966155.pcap
# Filtered pcap saved to ./filtered_pcap_357943595733515.pcap
# Filtered pcap saved to ./filtered_pcap_1564784311140266.pcap
# Filtered pcap saved to ./filtered_pcap_1912893560302462.pcap
# Filtered pcap saved to ./filtered_pcap_592652828112129.pcap
# Filtered pcap saved to ./filtered_pcap_1994766379099306.pcap
# Filtered pcap saved to ./filtered_pcap_1291598630700465.pcap
# Filtered pcap saved to ./filtered_pcap_2105069733892564.pcap
# Filtered pcap saved to ./filtered_pcap_792113271134668.pcap
# Filtered pcap saved to ./filtered_pcap_1534195587842936.pcap
# Filtered pcap saved to ./filtered_pcap_1849976618263433.pcap
# Filtered pcap saved to ./filtered_pcap_1051492808185216.pcap
# Filtered pcap saved to ./filtered_pcap_1770981436980565.pcap
# Filtered pcap saved to ./filtered_pcap_629812923758660.pcap
# Filtered pcap saved to ./filtered_pcap_1886730810322316.pcap
# Filtered pcap saved to ./filtered_pcap_2129483817813402.pcap
# Filtered pcap saved to ./filtered_pcap_326611195893853.pcap
# Filtered pcap saved to ./filtered_pcap_633104369983304.pcap
# Filtered pcap saved to ./filtered_pcap_13913985874972.pcap
# Filtered pcap saved to ./filtered_pcap_1968538610920594.pcap
# Filtered pcap saved to ./filtered_pcap_131213919991531.pcap
# Filtered pcap saved to ./filtered_pcap_949424558435287.pcap
# Filtered pcap saved to ./filtered_pcap_1970480042396430.pcap
# Filtered pcap saved to ./filtered_pcap_1117589739376654.pcap
# Filtered pcap saved to ./filtered_pcap_526759046791289.pcap
# Filtered pcap saved to ./filtered_pcap_2247007306417840.pcap
# Filtered pcap saved to ./filtered_pcap_1609926258408230.pcap
# Filtered pcap saved to ./filtered_pcap_1665483839308166.pcap
# Filtered pcap saved to ./filtered_pcap_604113709639173.pcap
# Filtered pcap saved to ./filtered_pcap_1825301801910534.pcap
# Filtered pcap saved to ./filtered_pcap_194803408279602.pcap
# Filtered pcap saved to ./filtered_pcap_2249421304837001.pcap
# Filtered pcap saved to ./filtered_pcap_2176121286556545.pcap
# Filtered pcap saved to ./filtered_pcap_476063750084706.pcap
# Filtered pcap saved to ./filtered_pcap_1975335942319872.pcap
# Filtered pcap saved to ./filtered_pcap_1776270667273491.pcap
# Filtered pcap saved to ./filtered_pcap_1911106885341487.pcap
